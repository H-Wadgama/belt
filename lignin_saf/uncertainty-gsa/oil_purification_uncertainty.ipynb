# %%
# RCF + cellulosic ethanol without dilute-acid pretreatment

from lignin_saf.ligsaf_chemicals import create_chemicals
from lignin_saf.settings.process_params import feed_parameters, solvolysis_params, hydrogenolysis_params, rcf_oil_yield, additional_rcf, etoac_purification, etoac_partition_IDs, etoac_partition_K
from lignin_saf.settings.prices import prices,  _feedstock_price_dry_ton, kg_per_ton, h2_price
from lignin_saf.settings.tea_params import operating_days, labor
from lignin_saf.systems.rcf import create_rcf_system
from lignin_saf.systems.cellulosic_ethanol_no_preatreatment import create_cellulosic_ethanol_system
from lignin_saf.cellulosic_tea import create_cellulosic_ethanol_tea
from lignin_saf.systems.rcf_oil_purification import create_rcf_oil_purification_system
from lignin_saf.ligsaf_units import HydrogenStorageTank


from biosteam import main_flowsheet as F
import biosteam as bst

chems = create_chemicals()
bst.settings.set_thermo(chems)
bst.settings.CEPCI = 840

chems.define_group(
    name='Poplar',
    IDs=['Glucan', 'Xylan', 'Arabinan', 'Mannan', 'Galactan',
         'Sucrose', 'Lignin', 'Acetate', 'Extract', 'Ash'],
    composition=[0.464, 0.134, 0.002, 0.037, 0.014,
                 0.001, 0.285, 0.035, 0.016, 0.012],
    wt=True
)

poplar_in = bst.Stream('Poplar_In',
                       Poplar=feed_parameters['flow'] * 1e3,
                       Water=feed_parameters['moisture'] * feed_parameters['flow'] * 1e3,
                       phase='l', units='kg/d', price=prices['Feedstock'])

# ── Area 200: RCF process ──────────────────────────────────────────────────
rcf_system = create_rcf_system(ins=poplar_in)
rcf_system.simulate()

rcf_oil_purification_sys = create_rcf_oil_purification_system(ins=F.RCF_CRUDE_OUT)
rcf_oil_purification_sys.simulate()

# ── Cellulosic ethanol — Carbohydrate_Pulp feeds directly into fermentation ─
etoh_system = create_cellulosic_ethanol_system(ins=F.Carbohydrate_Pulp)
etoh_system.simulate()

# No pretreatment_wastewater — only S401 stillage filtrate goes to WWT.
etoh_ww     = [F.unit.S401.outs[1]]
etoh_solids = [F.unit.S401.outs[0]]

# ── WWT: RCF wastewater + ethanol stillage filtrate ────────────────────────
WWT = bst.create_conventional_wastewater_treatment_system(
    'WWT',
    ins=[F.RCF_WW_OUTS, F.WW_10, F.WastePulp] + etoh_ww,
)
for unit in WWT.units:
    if hasattr(unit, 'strict_moisture_content'):
        unit.strict_moisture_content = False

# Wire WWT RO-treated water to PWC; create_all_facilities(WWT=False) leaves
# M2 (placeholder mixer) empty, so PWC would otherwise buy ~480,000 kg/hr
# of fresh water unnecessarily.
F.unit.PWC.ins[0] = WWT.outs[2]

solids_to_BT = bst.Mixer('MIX_BT_solids', ins=[WWT.outs[1]] + etoh_solids)
gas_mixer    = bst.Mixer('MIX_BT_gas',    ins=[F.RCF_PSAWASTE_OUTS, WWT.outs[0]])

BT = bst.facilities.BoilerTurbogenerator('BT', fuel_price=prices['CH4'])
BT.ins[0] = solids_to_BT.outs[0]
BT.ins[1] = gas_mixer.outs[0]



h2_rcf = bst.Stream()
h2_rcf.copy_like(F.RCF_H2_IN)

shared_h2_storage = HydrogenStorageTank('H2_TK', ins=h2_rcf)



rcf_pure_oil_system = bst.System(
    'RCF_OIL_system',
    path=(rcf_system, rcf_oil_purification_sys, etoh_system, WWT),
    facilities=[solids_to_BT, gas_mixer, BT, shared_h2_storage],
)

rcf_pure_oil_system.simulate()
integrated_tea = create_cellulosic_ethanol_tea(rcf_pure_oil_system)
F.ethanol.price = 0.8822293394025529


F.cellulase.price = prices['Cellulase'] 
F.CSL.price = prices ['CSL'] 
F.DAP.price = prices['DAP'] 
F.caustic.price = prices['Caustic']
F.denaturant.price =  prices['Denaturant'] 
F.cooling_tower_chemicals.price = prices['CT_chemicals']
# Out:
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\thermosteam\equilibrium\bubble_point.py:128: RuntimeWarning: Hydrogen has no defined Dortmund groups; functional group interactions are ignored
#   self.gamma = thermo.Gamma(chemicals)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\thermosteam\equilibrium\bubble_point.py:128: RuntimeWarning: Methane has no defined Dortmund groups; functional group interactions are ignored
#   self.gamma = thermo.Gamma(chemicals)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\thermosteam\equilibrium\dew_point.py:129: RuntimeWarning: Methane has no defined Dortmund groups; functional group interactions are ignored
#   self.gamma = thermo.Gamma(chemicals)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (2.45e+03 hp), head (3.35e+03 ft), kinematic viscosity (6.09e-07 m2/s), and NPSH (0.745 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel length (59.67 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:659: CostWarning: <HydrogenolysisReactor: RCF_RXR2> Vertical vessel length (41.79 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\_unit.py:986: RuntimeWarning: the purchase cost item, 'Catalyst loading cost', has no defined bare-module factor in the 'HydrogenolysisReactor.F_BM' dictionary; bare-module factor now has a default value of 1
#   warn(f"the purchase cost item, '{name}', has "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\_unit.py:1241: CostWarning: <IsentropicCompressor: RCF_COMP1> power (0 hp) is out of bounds (10 to 750 hp) for cost correlation
#   self._cost(**cost_kwargs) if cost_kwargs else self._cost()
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <Flash: RCF_FLSH2> Vertical vessel weight (660.2 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <Flash: RCF_FLSH2> Vertical vessel length (6.5 ft) is out of bounds (12 to 40 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel weight (104 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel length (2.241 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\_unit.py:986: RuntimeWarning: the purchase cost item, 'Adsorbent cost', has no defined bare-module factor in the 'PSA.F_BM' dictionary; bare-module factor now has a default value of 1
#   warn(f"the purchase cost item, '{name}', has "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel weight (77.76 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel length (1.256 ft) is out of bounds (12 to 40 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsSettler> Horizontal vessel diameter (2.792 ft) is out of bounds (3 to 21 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <Flash: FLASH201> Vertical vessel length (10.5 ft) is out of bounds (12 to 40 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <RefluxDrum: reflux_drum> Vertical vessel length (9 ft) is out of bounds (12 to 40 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (29519 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\_unit.py:986: RuntimeWarning: the purchase cost item, 'Total Cost', has no defined bare-module factor in the 'HydrogenStorageTank.F_BM' dictionary; bare-module factor now has a default value of 1
#   warn(f"the purchase cost item, '{name}', has "

# %%
F.ethanol
# Out:
# Stream: ethanol from <StorageTank: T703>
# phase: 'l', T: 339.26 K, P: 101325 Pa
# flow (kmol/hr): Water       8.44
#                 Ethanol     397
#                 Denaturant  3.55

# %%
(0. * chems['Ethanol'].rho('l', 339, 101325))/264.172
# Out:
# 2.2669842303752934

# %%
(2.5* 264.172)/(chems['Ethanol'].rho('l', 339, 101325))
# Out:
# 0.8822293394025529

# %%
# Labor cost from [1]
# [1] W. Seider et al., Product and Process Design Principles. 2016. John Wiley & Sons.
# Table 17.3 from [1]
# For RCF - 6 operators for the reactors (solids-fluids processing, and > 100 ton/day so 3 x 2 =6 ), and 2 for the distillation columns downstream for solvent recovery. Total operators: 8
# For oil purification 2 operators Total operator: 2

# For ethanol production, 6 operators for reactors as solids-fluids processing and large volumes so 3 x 2 = 6, and then 2 for the beer column downstream for ethanol purification. Total operators: 8
# 1 operators for the storage. Total operators: 1
# 1 operators for WWT (I think complexity of feed streams), and 1 for BT. Total operator: 2
# Total operators per shift: 21

num_operators_per_shift = 21
num_shifts              = 5       # number of operator shifts (4 working + 1 relief)
pay_rate                = 40      # [USD/hr] operator base pay rate

DWandB             = num_operators_per_shift * num_shifts * 2080 * pay_rate
Dsalaries_benefits = 0.15 * DWandB          # 15% of DW&B for salaried staff + benefits
O_supplies         = 0.06 * DWandB          # 6% of DW&B for operating supplies
technical_assistance = 5 * 75_000           # 5 technical staff @ $75,000/yr
control_lab          = 5 * 80_000           # 5 lab/QC staff  @ $80,000/yr

labor = DWandB + Dsalaries_benefits + O_supplies + technical_assistance + control_lab
# [USD/yr] total annual labor cost; passed to tea.labor_cost after creating the TEA object

# %%
integrated_tea.operating_days = 330
integrated_tea.labor_cost = labor

# %%
msp = round((integrated_tea.solve_price(F.PURE_OIL_OUT)),2)
print(f'The MSP for RCF crude is  {msp} USD/kg')
# Out:
# The MSP for RCF crude is  2.32 USD/kg

# %%
model = bst.Model(rcf_pure_oil_system)

# %%
from chaospy import distributions as shape
param = model.parameter

# %%
var_50 = 0.5 # 50% variation in parameters - set for a few
var_20 = 0.2 # 20% variation in other parameters

# %%
# Operating days — kind='isolated': only affects TEA time scaling, not mass/energy balance
dist = shape.Uniform(lower = 297 , upper = 363)
@param(name = 'Operating days',
    element = 'Overall',
    kind = 'isolated',
    units = 'days',
    baseline = integrated_tea.operating_days,
    distribution = dist)
def set_opertaing_days(i):
    integrated_tea.operating_days = i


# Poplar feedstock
dist = shape.Uniform(lower = 50 , upper = 100)
@param(name = 'Poplar feedstock price',
    element = 'Overall',
    kind = 'isolated',
    units = 'USD/DMT',
    baseline = _feedstock_price_dry_ton,
    distribution = dist)
def set_poplar_feedstock_price(i):
    # i is in USD/dry short ton; stream price must be USD/kg wet biomass
    F.Poplar_In.price = i / kg_per_ton / (1 + feed_parameters['moisture'])



# Labor cost
dist = shape.Uniform(lower = integrated_tea.labor_cost * (1-var_50) , upper = integrated_tea.labor_cost * (1+var_50) )
@param(name = 'Labor cost',
    element = 'Overall',
    kind = 'isolated',
    units = 'USD/yr',
    baseline = integrated_tea.labor_cost,
    distribution = dist)
def set_labor_cost(i): 
    integrated_tea.labor_cost = i


# Electricity price
dist = shape.Triangle(lower = 0.0641, midpoint = bst.settings.electricity_price, upper = 0.1798) 
@param(name = 'Electricity cost',
    element = 'Overall', 
    kind = 'isolated',
    units = 'USD/kWh',
    baseline = bst.settings.electricity_price, distribution = dist)
def set_electricity_price(i):
    bst.settings.electricity_price = i  



# Hydrogen price
dist = shape.Triangle(lower = 2.74 , midpoint=3.70, upper = 11.53)
@param(name = 'Hydrogen price',
       element = 'Overall',
       kind = 'isolated',
       units = 'USD/kg',
       baseline =  h2_price,
       distribution = dist)
def set_hydrogen_price(i):
    F.RCF_H2_IN.price = i


# Hydrogen storage time
dist = shape.Uniform(lower = 0.25 , upper = 3)
@param(name = 'Hydrogen storage period',
       element = 'Overall',
       kind = 'isolated',
       units = 'days',
       baseline =  F.H2_TK.storage_period,
       distribution = dist)
def set_h2_storage_period(i):
    F.H2_TK.storage_period = i
    F.H2_TK.simulate()   # re-runs _design()/_cost() so CAPEX updates for solve_price()

# %%
# Solvolysis pressure
dist = shape.Uniform(lower = solvolysis_params['P'],  upper = 83.3e5)
@param(name = 'Solvolysis reactor pressure',
    element = 'RCF', 
    kind = 'coupled',
    units = 'Pa',
    baseline = solvolysis_params['P'], distribution = dist)
def set_solvolysis_rxr_pressure(i):
    F.RCF_RXR1.P = i  



# Solvolysis reaction time
dist = shape.Triangle(lower = 3*(1-var_50), midpoint = 3, upper = 3*(1+var_50))
@param(name = 'Solvolysis reaction time',
    element = 'RCF', 
    kind = 'coupled',
    units = 'hr',
    baseline = solvolysis_params['tau_s'], distribution = dist)
def set_solvolysis_reaction_time(i):
    F.RCF_RXR1.tau = i      


# Solvolysis residence time
dist = shape.Triangle(lower = 9/60, midpoint = solvolysis_params['tau_s_res'], upper = 36/60) 
@param(name = 'Solvolysis residence time',
    element = 'RCF', 
    kind = 'coupled',
    units = 'hr',
    baseline = solvolysis_params['tau_s_res'], distribution = dist)
def set_solvolysis_residence_time(i):
    F.RCF_RXR1.tau_residence = i  


# Solvolysis cleaning time
dist = shape.Triangle(lower = 0.5, midpoint = 1, upper = 2) 
@param(name = 'Solvolysis cleaning time',
    element = 'RCF', 
    kind = 'coupled',
    units = 'hr',
    baseline = F.RCF_RXR1.tau_0, distribution = dist)
def set_solvolysis_cleaning_time(i):
    F.RCF_RXR1.tau_0 = i  


# Methanol price
dist = shape.Triangle(lower = 0.2648, midpoint = F.RCF_MEOH_IN.price, upper = 0.3972)
@param(name = 'Methanol cost',
    element = 'RCF', 
    kind = 'isolated',
    units = 'USD/kg',
    baseline = F.RCF_MEOH_IN.price, distribution = dist)
def set_methanol_price(i):
    F.RCF_MEOH_IN.price = i  

# Solvent losses in pulp
dist = shape.Uniform(lower=0.005, upper=0.05)
@param(name='RCF solvent losses',
       element='RCF',
       kind='coupled',
       units='-',
       baseline=solvolysis_params['solvent_losses'],
       distribution=dist)
def set_solvent_losses(i):
    solvolysis_params['solvent_losses'] = i

# RCF reactor duty
dist = shape.Uniform(lower=49, upper=72)
@param(name='RCF reactor duty',
       element='RCF',
       kind='coupled',
       units='-',
       baseline=hydrogenolysis_params['duty'],
       distribution=dist)
def set_rcf_reactor_duty(i):
    hydrogenolysis_params['duty'] = i


# RCF catalyst cost 
dist = shape.Uniform(lower = F.RCF_CAT_IN.price * (0.1), upper = F.RCF_CAT_IN.price * (10) )  # Same variation as Bartling et al
@param(name = 'RCF catalyst price',
    element = 'RCF', 
    kind = 'isolated',
    units = 'USD/kg',
    baseline = F.RCF_CAT_IN.price, distribution = dist)
def set_rcf_catalyst_price(i):
    F.RCF_CAT_IN.price = i      



# RCF catalyst lifetime 
dist = shape.Uniform(lower = 1, upper = 36)  # Same as Bartling et al
@param(name = 'RCF catalyst lifetime',
    element = 'RCF', 
    kind = 'isolated',
    units = 'months',
    baseline = solvolysis_params['cat_lifetime'], distribution = dist)
def set_rcf_catalyst_lifetime(i):
    solvolysis_params['cat_lifetime'] = i
    F.RCF_CAT_IN.imass['NiC'] = (
        solvolysis_params['cat_loading'] * (feed_parameters['flow'] * 1e3 / 24) * solvolysis_params['tau_h']
    ) / (i * 30 * 24)   # [kg/hr]


# RCF catalyst loading 
dist = shape.Uniform(lower = solvolysis_params['cat_loading'] * (1-var_50) , upper = solvolysis_params['cat_loading'] * (1+var_50) ) 
@param(name = 'RCF catalyst loading',
    element = 'RCF', 
    kind = 'isolated',
    units = 'kg/kg-biomass',
    baseline = solvolysis_params['cat_loading'], distribution = dist)
def set_rcf_catalyst_loading(i):
    solvolysis_params['cat_loading'] = i 
    F.RCF_CAT_IN.imass['NiC'] = (
        i * (feed_parameters['flow'] * 1e3 / 24) * solvolysis_params['tau_h']
    ) / (solvolysis_params['cat_lifetime'] * 30 * 24)   # [kg/hr]

# Cellulose retention
dist = shape.Triangle(lower=0.8, midpoint = solvolysis_params['Cellulose_retention'], upper=1.0)
@param(name='Cellulose retention',
       element='RCF',
       kind='coupled',
       units='%',
       baseline=solvolysis_params['Cellulose_retention'],
       distribution=dist)
def set_cellulose_retention(i):
    solvolysis_params['Cellulose_retention'] = i


# Xylose retention
dist = shape.Triangle(lower=0.2, midpoint = solvolysis_params['Xylose_retention'], upper=1.0)
@param(name='Xylose retention',
       element='RCF',
       kind='coupled',
       units='%',
       baseline=solvolysis_params['Xylose_retention'],
       distribution=dist)
def set_xylose_retention(i):
    solvolysis_params['Xylose_retention'] = i


# Delignification
dist = shape.Triangle(lower = 0.4 , midpoint = solvolysis_params['Delignification'], upper = 0.9)
@param(name = 'Delignfication',
       element = 'RCF',
       kind = 'coupled',
       units = '%',
       baseline = solvolysis_params['Delignification'], distribution = dist)
def set_delignfication(i):
    solvolysis_params['Delignification'] = i
    F.RCF_RXR1.reaction_1.X = i   


# Condensation extent
dist = shape.Triangle(lower = 0.001 , midpoint = hydrogenolysis_params['condensation_extent'], upper = 0.709)
@param(name = 'Condensation extent',
       element = 'RCF',
       kind = 'coupled',
       units = '%',
       baseline = hydrogenolysis_params['condensation_extent'], distribution = dist)
def set_condensation_extent(i):
    _X_scale = 1.0 - 1e-6
    hydrogenolysis_params['condensation_extent'] = i
    # X values are baked into the ParallelReaction at create_rcf_system() time; must update directly.
    # Reactions 0 & 1: Propylguaiacol/Propylsyringol (monomers that escaped condensation).
    # Reactions 4 & 5: S_Oligomer/G_Oligomer (baseline oligomers + condensed monomer fraction).
    F.RCF_RXR2.reaction[0].X = _X_scale * rcf_oil_yield['Monomers'] * 0.5 * (1 - i)
    F.RCF_RXR2.reaction[1].X = _X_scale * rcf_oil_yield['Monomers'] * 0.5 * (1 - i)
    F.RCF_RXR2.reaction[4].X = _X_scale * (rcf_oil_yield['Oligomers'] * 0.5 + rcf_oil_yield['Monomers'] * 0.5 * i)
    F.RCF_RXR2.reaction[5].X = _X_scale * (rcf_oil_yield['Oligomers'] * 0.5 + rcf_oil_yield['Monomers'] * 0.5 * i)


# Distillation col 1 light key recovery at the top
dist = shape.Uniform(lower = 0.7, 
                     upper = 0.9999) 
@param(name = 'Light key recovery - column 1',
    element = 'RCF', 
    kind = 'coupled',
    units = 'wt%',
    baseline = additional_rcf['rcf_col_1_light_dist_recovery'], distribution = dist)
def set_light_key_recovery_column_1(i):
    additional_rcf['rcf_col_1_light_dist_recovery'] = i
    F.unit.RCF_COL1.Lr = i

# %%
# Glucose to ethanol conversion
dist = shape.Triangle(lower = 0.8, midpoint = F.R303.cofermentation[0].X, upper = 0.95)
@param(name = 'Glucose to ethanol conv.',
    element = 'EHF', 
    kind = 'coupled',
    units = '-',
    baseline = F.R303.cofermentation[0].X, distribution = dist)
def set_glucose_to_ethanol_conv(i):
    F.R303.cofermentation[0].X = i  

# Glucan to glucose conversion 
dist = shape.Triangle(lower = 0.8, midpoint = F.R303.saccharification[2].X,  upper = 0.9)
@param(name = 'Glucan to glucose conv.',
    element = 'EHF', 
    kind = 'coupled',
    units = '-',
    baseline = F.R303.saccharification[2].X, distribution = dist)
def set_glucan_to_glucose_conv(i):
    F.R303.saccharification[2].X = i  


# Saccharification residence time
dist = shape.Triangle(lower = 60 * (1-var_20), midpoint = F.R303.tau_saccharification, upper = 60 * (1+var_20))
@param(name = 'Saccharification residence time',
    element = 'EHF', 
    kind = 'coupled',
    units = 'hr',
    baseline = F.R303.tau_saccharification, distribution = dist)
def set_saccharification_tau(i):
    F.R303.tau_saccharification = i  

# Cofermentation residence time
dist = shape.Triangle(lower = 36 * (1-var_20),  midpoint = F.R303.tau_cofermentation, upper = 36 * (1+var_20))
@param(name = 'Cofermentation residence time',
    element = 'EHF', 
    kind = 'coupled',
    units = 'hr',
    baseline = F.R303.tau_cofermentation, distribution = dist)
def set_cofermentation_tau(i):
    F.R303.tau_cofermentation = i  


# Xylose to ethanol conversion
dist = shape.Triangle(lower = 0.8, midpoint =  F.R303.cofermentation[4].X, upper = 0.9)
@param(name = 'Xylose to ethanol conv.',
    element = 'EHF', 
    kind = 'coupled',
    units = '-',
    baseline = F.R303.cofermentation[4].X, distribution = dist)
def set_xylose_to_ethanol_conv(i):
    F.R303.cofermentation[4].X = i      

# Xylan to xylose conversion
dist = shape.Triangle(lower=0.8, midpoint = F.unit.R301.reactions[0].X , upper=0.9)
@param(name='Xylan to xylose conversion',
       element='Cellulosic ethanol',
       kind='coupled',
       units='-',
       baseline=F.unit.R301.reactions[0].X,
       distribution=dist)
def set_xylan_to_xylose_conversion(i):
    F.unit.R301.reactions[0].X = i



# Cellulase enzyme loading
dist = shape.Triangle(lower = 0.01, midpoint = F.M301.enzyme_loading, upper = 0.05)
@param(name = 'Cellulase enzyme loading',
    element = 'EHF', 
    kind = 'coupled',
    units = 'wt%',
    baseline = F.M301.enzyme_loading, distribution = dist)
def set_enzyme_loading(i):
    F.M301.enzyme_loading = i  


# Cellulase price
dist = shape.Uniform(lower = F.M301.ins[1].price * (1-var_50), upper = F.M301.ins[1].price * (1+var_50))
@param(name = 'Cellulase price',
    element = 'EHF',
    kind = 'isolated',
    units = 'USD/kg',
    baseline = F.M301.ins[1].price, distribution = dist)
def set_cellulase_price(i):
    F.M301.ins[1].price = i

# Ethanol co-product revenue 
dist = shape.Uniform(lower = F.ethanol.price*(1-var_50), upper = F.ethanol.price*(1+var_50))
@param(name = 'Ethanol price',
    element = 'EHF',
    kind = 'isolated',
    units = 'USD/kg',
    baseline = F.ethanol.price, distribution = dist)
def set_ethanol_price(i):
    F.ethanol.price = i

# %%
# Etyl acetate solvent to crude RCF oil ratio
dist = shape.Uniform(lower=etoac_purification['solvent_to_crude_ratio'] * (1 - var_20),
                     upper=etoac_purification['solvent_to_crude_ratio'] * (1 + var_20))
@param(name='EtOAc solvent to crude ratio',
       element='OP',
       kind='coupled',
       units='L/kg',
       baseline=etoac_purification['solvent_to_crude_ratio'],
       distribution=dist)
def set_etoac_solvent_to_crude_ratio(i):
    etoac_purification['solvent_to_crude_ratio'] = i


# Ethyl acetate price
dist = shape.Uniform(lower = F.EthylAcetate_in.price * (1-var_50), upper = F.EthylAcetate_in.price * (1+var_50))
@param(name = 'Ethyl acetate price',
    element = 'OP', 
    kind = 'isolated',
    units = 'USD/kg',
    baseline = F.EthylAcetate_in.price, distribution = dist)
def set_ethyl_acetate_price(i):
    F.EthylAcetate_in.price = i

# %%
metric = model.metric
@metric(name='Minimum Jet Selling Price', element='TEA', units='USD/gal')
def get_msp():
    msp = (integrated_tea.solve_price(F.PURE_OIL_OUT))
    return msp

# %%
import numpy as np
np.random.seed(3194)
samples = model.sample(N=3000, rule = 'L')  # Change this to 3000 later
model.load_samples(samples)

# %%
model.evaluate()
# Out:
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (3.72e+03 hp), head (3.29e+03 ft), kinematic viscosity (6.48e-07 m2/s), and NPSH (5.75 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel length (42.74 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:659: CostWarning: <HydrogenolysisReactor: RCF_RXR2> Vertical vessel length (42.1 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\_unit.py:1241: CostWarning: <IsentropicCompressor: RCF_COMP1> power (9.293e-13 hp) is out of bounds (10 to 750 hp) for cost correlation
#   self._cost(**cost_kwargs) if cost_kwargs else self._cost()
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <Flash: RCF_FLSH2> Vertical vessel weight (660.2 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <Flash: RCF_FLSH2> Vertical vessel length (6.5 ft) is out of bounds (12 to 40 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel weight (132.8 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel length (2.532 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel weight (88.95 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel length (1.344 ft) is out of bounds (12 to 40 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <Flash: FLASH201> Vertical vessel length (11.5 ft) is out of bounds (12 to 40 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <RefluxDrum: reflux_drum> Vertical vessel length (9.5 ft) is out of bounds (12 to 40 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (24034 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (4.62e+03 hp), head (3.28e+03 ft), kinematic viscosity (6.73e-07 m2/s), and NPSH (9.28 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <Flash: RCF_FLSH1> Horizontal vessel diameter (22 ft) is out of bounds (3 to 21 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\_unit.py:1241: CostWarning: <IsentropicCompressor: RCF_COMP1> power (2.478e-12 hp) is out of bounds (10 to 750 hp) for cost correlation
#   self._cost(**cost_kwargs) if cost_kwargs else self._cost()
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <Flash: RCF_FLSH2> Vertical vessel weight (1083 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   return method(pressure, diameter, length)
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel weight (155.2 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel length (2.737 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\_unit.py:1241: CostWarning: <IsentropicCompressor: vaccuum_pump> power (758.5 hp) is out of bounds (10 to 750 hp) for cost correlation
#   self._cost(**cost_kwargs) if cost_kwargs else self._cost()
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:1007: CostWarning: <IsentropicCompressor: vaccuum_pump> power (758.5 hp) is out of bounds (10 to 750 hp) for cost correlation
#   self.vaccuum_pump._cost()
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel weight (97.07 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel length (1.404 ft) is out of bounds (12 to 40 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <Flash: FLASH201> Vertical vessel length (10.5 ft) is out of bounds (12 to 40 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (23568 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (2.52e+03 hp), head (3.33e+03 ft), kinematic viscosity (6.54e-07 m2/s), and NPSH (9.91 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel length (45.37 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\_unit.py:1241: CostWarning: <IsentropicCompressor: RCF_COMP1> power (0 hp) is out of bounds (10 to 750 hp) for cost correlation
#   self._cost(**cost_kwargs) if cost_kwargs else self._cost()
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel weight (104.5 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel length (2.246 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel weight (86.47 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel length (1.325 ft) is out of bounds (12 to 40 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (26857 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (1.88e+03 hp), head (3.39e+03 ft), kinematic viscosity (6.31e-07 m2/s), and NPSH (10.8 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel length (63.8 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel weight (108.2 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel length (2.285 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel weight (105 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel length (1.46 ft) is out of bounds (12 to 40 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <RefluxDrum: reflux_drum> Vertical vessel length (9 ft) is out of bounds (12 to 40 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (24886 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (1.65e+03 hp), head (3.42e+03 ft), kinematic viscosity (6.34e-07 m2/s), and NPSH (11.6 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel length (60.8 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel weight (95.48 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel length (2.147 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel weight (93.52 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel length (1.378 ft) is out of bounds (12 to 40 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (25406 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (1.57e+03 hp), head (3.43e+03 ft), kinematic viscosity (6.42e-07 m2/s), and NPSH (10.6 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel length (60.31 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:659: CostWarning: <HydrogenolysisReactor: RCF_RXR2> Vertical vessel length (42.64 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel weight (76 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel length (1.915 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel weight (76.27 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel length (1.244 ft) is out of bounds (12 to 40 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsSettler> Horizontal vessel diameter (2.751 ft) is out of bounds (3 to 21 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (27297 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (1.77e+03 hp), head (3.41e+03 ft), kinematic viscosity (6.36e-07 m2/s), and NPSH (10.6 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel length (54.98 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel weight (92.24 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel length (2.11 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel weight (82.06 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel length (1.291 ft) is out of bounds (12 to 40 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsSettler> Horizontal vessel diameter (2.907 ft) is out of bounds (3 to 21 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (27072 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (1.91e+03 hp), head (3.39e+03 ft), kinematic viscosity (6.37e-07 m2/s), and NPSH (10 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel length (57.52 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel weight (95.07 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel length (2.142 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel weight (79.1 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel length (1.267 ft) is out of bounds (12 to 40 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsSettler> Horizontal vessel diameter (2.828 ft) is out of bounds (3 to 21 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (28790 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (2.92e+03 hp), head (3.32e+03 ft), kinematic viscosity (6.24e-07 m2/s), and NPSH (3.61 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel length (40.83 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\_unit.py:1241: CostWarning: <IsentropicCompressor: RCF_COMP1> power (2.943e-12 hp) is out of bounds (10 to 750 hp) for cost correlation
#   self._cost(**cost_kwargs) if cost_kwargs else self._cost()
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel weight (120 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel length (2.407 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel weight (78.73 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel length (1.264 ft) is out of bounds (12 to 40 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsSettler> Horizontal vessel diameter (2.818 ft) is out of bounds (3 to 21 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (29657 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (2.81e+03 hp), head (3.33e+03 ft), kinematic viscosity (6.15e-07 m2/s), and NPSH (2.37 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel weight (1.282e+06 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel length (44.89 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel weight (120.4 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel length (2.411 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel weight (85.34 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel length (1.316 ft) is out of bounds (12 to 40 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsSettler> Horizontal vessel diameter (2.993 ft) is out of bounds (3 to 21 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (28207 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (2.96e+03 hp), head (3.31e+03 ft), kinematic viscosity (6.4e-07 m2/s), and NPSH (6.6 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel weight (1.484e+06 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel length (45.64 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\_unit.py:1241: CostWarning: <IsentropicCompressor: RCF_COMP1> power (1.859e-12 hp) is out of bounds (10 to 750 hp) for cost correlation
#   self._cost(**cost_kwargs) if cost_kwargs else self._cost()
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel weight (119.5 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel length (2.402 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel weight (79.78 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel length (1.273 ft) is out of bounds (12 to 40 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsSettler> Horizontal vessel diameter (2.846 ft) is out of bounds (3 to 21 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (28211 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (2.86e+03 hp), head (3.32e+03 ft), kinematic viscosity (6.33e-07 m2/s), and NPSH (5.21 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel weight (1.41e+06 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel length (45.95 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel weight (114.8 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel length (2.354 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel weight (82.22 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel length (1.292 ft) is out of bounds (12 to 40 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsSettler> Horizontal vessel diameter (2.911 ft) is out of bounds (3 to 21 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (27167 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (2.52e+03 hp), head (3.34e+03 ft), kinematic viscosity (6.33e-07 m2/s), and NPSH (6.27 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel weight (1.15e+06 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel length (47.25 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\_unit.py:1241: CostWarning: <IsentropicCompressor: RCF_COMP1> power (3.407e-12 hp) is out of bounds (10 to 750 hp) for cost correlation
#   self._cost(**cost_kwargs) if cost_kwargs else self._cost()
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel weight (106.9 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel length (2.271 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel weight (86.73 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel length (1.327 ft) is out of bounds (12 to 40 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (26121 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (2.44e+03 hp), head (3.34e+03 ft), kinematic viscosity (6.3e-07 m2/s), and NPSH (8.35 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel weight (1.296e+06 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel length (49.65 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\_unit.py:1241: CostWarning: <IsentropicCompressor: RCF_COMP1> power (3.098e-13 hp) is out of bounds (10 to 750 hp) for cost correlation
#   self._cost(**cost_kwargs) if cost_kwargs else self._cost()
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel weight (122.5 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel length (2.432 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel weight (100.3 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel length (1.427 ft) is out of bounds (12 to 40 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (25363 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (2.78e+03 hp), head (3.31e+03 ft), kinematic viscosity (6.48e-07 m2/s), and NPSH (8.41 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel weight (1.234e+06 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:659: CostWarning: <HydrogenolysisReactor: RCF_RXR2> Vertical vessel length (43.14 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel weight (113.3 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel length (2.339 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel weight (90.92 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel length (1.359 ft) is out of bounds (12 to 40 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (25382 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (1.44e+03 hp), head (3.47e+03 ft), kinematic viscosity (6.21e-07 m2/s), and NPSH (9.18 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel length (55.15 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\_unit.py:1241: CostWarning: <IsentropicCompressor: RCF_COMP1> power (1.549e-13 hp) is out of bounds (10 to 750 hp) for cost correlation
#   self._cost(**cost_kwargs) if cost_kwargs else self._cost()
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <Flash: RCF_FLSH2> Vertical vessel weight (362.8 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   return method(pressure, diameter, length)
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel weight (81.99 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel length (1.989 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel weight (92.27 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel length (1.369 ft) is out of bounds (12 to 40 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (24581 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (1.59e+03 hp), head (3.44e+03 ft), kinematic viscosity (6.22e-07 m2/s), and NPSH (8.69 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel length (52.36 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\_unit.py:1241: CostWarning: <IsentropicCompressor: RCF_COMP1> power (6.195e-13 hp) is out of bounds (10 to 750 hp) for cost correlation
#   self._cost(**cost_kwargs) if cost_kwargs else self._cost()
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel weight (86.85 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel length (2.047 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel weight (95.67 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel length (1.394 ft) is out of bounds (12 to 40 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (25709 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (2.16e+03 hp), head (3.37e+03 ft), kinematic viscosity (6.26e-07 m2/s), and NPSH (5.9 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\_unit.py:1241: CostWarning: <IsentropicCompressor: RCF_COMP1> power (2.323e-13 hp) is out of bounds (10 to 750 hp) for cost correlation
#   self._cost(**cost_kwargs) if cost_kwargs else self._cost()
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel weight (97.08 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel length (2.164 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel weight (88.33 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel length (1.339 ft) is out of bounds (12 to 40 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (25931 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (2.2e+03 hp), head (3.36e+03 ft), kinematic viscosity (6.33e-07 m2/s), and NPSH (6.94 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel weight (1.037e+06 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\_unit.py:1241: CostWarning: <IsentropicCompressor: RCF_COMP1> power (6.969e-13 hp) is out of bounds (10 to 750 hp) for cost correlation
#   self._cost(**cost_kwargs) if cost_kwargs else self._cost()
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel weight (96.14 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel length (2.154 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel weight (86.5 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (26296 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (3.36e+03 hp), head (3.3e+03 ft), kinematic viscosity (6.32e-07 m2/s), and NPSH (3.05 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel weight (1.015e+06 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel weight (122.7 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel length (2.434 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# ...
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (24197 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (1.11e+03 hp), head (3.55e+03 ft), kinematic viscosity (6.19e-07 m2/s), and NPSH (12.9 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel weight (1.774e+06 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (23882 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (2.27e+03 hp), head (3.34e+03 ft), kinematic viscosity (6.61e-07 m2/s), and NPSH (12.3 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (25337 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (1.82e+03 hp), head (3.42e+03 ft), kinematic viscosity (6e-07 m2/s), and NPSH (4.32 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel weight (99.86 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (2.32e+03 hp), head (3.36e+03 ft), kinematic viscosity (6.15e-07 m2/s), and NPSH (5.12 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (22675 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (3.08e+03 hp), head (3.31e+03 ft), kinematic viscosity (6.31e-07 m2/s), and NPSH (5.29 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel weight (87.17 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (22206 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (6.4e+03 hp), head (3.28e+03 ft), kinematic viscosity (6.57e-07 m2/s), and NPSH (4.58 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <Flash: RCF_FLSH1> Horizontal vessel diameter (25 ft) is out of bounds (3 to 21 ft) for cost correlation
#   return method(pressure, diameter, length)
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel weight (194.5 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel length (3.064 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\_unit.py:1241: CostWarning: <IsentropicCompressor: vaccuum_pump> power (1034 hp) is out of bounds (10 to 750 hp) for cost correlation
#   self._cost(**cost_kwargs) if cost_kwargs else self._cost()
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:1007: CostWarning: <IsentropicCompressor: vaccuum_pump> power (1034 hp) is out of bounds (10 to 750 hp) for cost correlation
#   self.vaccuum_pump._cost()
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (26742 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (3.23e+03 hp), head (3.31e+03 ft), kinematic viscosity (6.16e-07 m2/s), and NPSH (3.44 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel weight (146.4 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel length (2.658 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (28486 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (1.96e+03 hp), head (3.4e+03 ft), kinematic viscosity (6.13e-07 m2/s), and NPSH (6.35 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel length (48.46 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (1.86e+03 hp), head (3.41e+03 ft), kinematic viscosity (6.04e-07 m2/s), and NPSH (2.58 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel weight (90.64 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (1.4e+03 hp), head (3.49e+03 ft), kinematic viscosity (5.86e-07 m2/s), and NPSH (2.17 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel length (47.12 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel weight (89.26 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (1.88e+03 hp), head (3.41e+03 ft), kinematic viscosity (5.95e-07 m2/s), and NPSH (2.26 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel length (46.69 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <LiquidsMixingTank> Vertical vessel weight (86.7 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (24502 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (2.41e+03 hp), head (3.35e+03 ft), kinematic viscosity (6.22e-07 m2/s), and NPSH (4.27 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel weight (1.562e+06 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (1.23e+03 hp), head (3.52e+03 ft), kinematic viscosity (6.01e-07 m2/s), and NPSH (5.47 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel weight (2.297e+06 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel weight (70.19 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel length (1.84 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (24314 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (951 hp), head (3.61e+03 ft), kinematic viscosity (6.09e-07 m2/s), and NPSH (12.2 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel weight (77.54 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel length (1.934 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (25162 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (1.5e+03 hp), head (3.45e+03 ft), kinematic viscosity (6.28e-07 m2/s), and NPSH (12.3 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel weight (2.454e+06 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:962: CostWarning: <PSA: RCF_PSA1> Vertical vessel weight (94.65 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (21947 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (2.89e+03 hp), head (3.3e+03 ft), kinematic viscosity (6.7e-07 m2/s), and NPSH (11.6 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\tank_design.py:107: CostWarning: volume (24003 gal) is below the lower bound (30000 gal) for purchase cost estimation
#   warn(f"volume ({V_total:.5g} {V_units}) is below "
# c:\Users\hwadg\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\_pump.py:224: RuntimeWarning: <Pump: RCF_PUMP1> no pump type available at current power (2.65e+03 hp), head (3.33e+03 ft), kinematic viscosity (6.33e-07 m2/s), and NPSH (8.04 ft); assuming centrigugal pump
#   warn(f'{repr(self)} no pump type available at current power '
# c:\users\hwadg\onedrive - the pennsylvania state university\shi_wadgama_shared\models\atjspk\lignin_saf\ligsaf_units.py:410: CostWarning: <SolvolysisReactor: RCF_RXR1> Vertical vessel weight (1.505e+06 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(

# %%
df_rho, df_p = model.spearman_r()
print(df_rho["TEA", "Minimum jet selling price [USD/gal]"])
# Out:
# Element             Parameter
# Overall             Operating days [days]                   -0.0327
#                     Poplar feedstock price [USD/DMT]         0.0916
#                     Labor cost [USD/yr]                      0.0153
#                     Electricity cost [USD/kWh]                0.011
#                     Hydrogen price [USD/kg]                  0.0503
#                     Hydrogen storage period [days]           0.0449
# RCF                 Solvolysis reactor pressure [Pa]        -0.0384
#                     Solvolysis reaction time [hr]             0.371
#                     Solvolysis residence time [hr]           -0.472
#                     Solvolysis cleaning time [hr]            0.0207
#                     Methanol cost [USD/kg]                    0.145
#                     RCF solvent losses [-]                   0.0241
#                     RCF reactor duty [-]                    -0.0244
#                     RCF catalyst price [USD/kg]             -0.0223
#                     RCF catalyst lifetime [months]           0.0195
#                     RCF catalyst loading [kg/kg-biomass]     0.0251
#                     Cellulose retention [%]                  0.0308
#                     Xylose retention [%]                    -0.0602
#                     Delignfication [%]                       -0.361
#                     Condensation extent [%]                  0.0152
#                     Light key recovery - column 1 [wt%]        -0.6
# EHF                 Glucose to ethanol conv. [-]            -0.0133
#                     Glucan to glucose conv. [-]             -0.0286
#                     Saccharification residence time [hr]     0.0339
#                     Cofermentation residence time [hr]     -0.00568
#                     Xylose to ethanol conv. [-]             0.00303
# Cellulosic ethanol  Xylan to xylose conversion [-]           0.0174
# EHF                 Cellulase enzyme loading [wt%]            0.113
#                     Cellulase price [USD/kg]                 0.0993
# OP                  Et oac solvent to crude ratio [L/kg]   -0.00908
#                     Ethyl acetate price [USD/kg]             0.0129
# Name: (TEA, Minimum jet selling price [USD/gal]), dtype: float64

# %%
model.table.to_excel('oil_trial_1.xlsx')

# %%
df_rho["TEA", "Minimum jet selling price [USD/gal]"].to_excel('spearman_oil_purification.xlsx')

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rc('font',family='Arial')

# Assume rho, labels, and model.parameters as before
N =  10 # Number of top parameters to plot
rho = df_rho["TEA", "Minimum jet selling price [USD/gal]"]
labels = [i.describe() for i in model.parameters]
values = rho.values

sorted_idx = np.argsort(np.abs(values))[::-1]
top_idx = sorted_idx[:N]
values_top = values[top_idx]
labels_top = np.array(labels)[top_idx]
colors = ['#40B0A6' if v > 0 else '#E1BE6A' for v in values_top]

fig, ax = plt.subplots(figsize=(8, max(5, N * 0.5)))
y_pos = np.arange(N)

# Add edgecolor and linewidth to the barh call
ax.barh(
    y_pos,
    values_top,
    color=colors,
    linewidth=1.5          # Border thickness
)


ax.axvline(x=0, color='k', linewidth=1.3, zorder=0)

ax.set_yticks(y_pos)
ax.set_yticklabels(labels_top, fontsize=11)
ax.invert_yaxis()

ax.set_xlabel("Spearman's correlation with Minimum jet selling price [USD/gal]")
#ax.set_title(f"Top {N} Sensitivity Parameters (Spearman's rho)")
'''
from matplotlib.patches import Patch
legend_elements = [
    Patch(facecolor='#B22222', edgecolor='black', label='Increase raises MJSP'),
    Patch(facecolor='#4682B4', edgecolor='black', label='Increase lowers MJSP'),
]
ax.legend(handles=legend_elements, loc='lower right')
'''
#plt.savefig('gsa_2_10000_spearman_2.png', dpi = 300, bbox_inches = 'tight')
plt.tight_layout()
plt.show()
